# %% [markdown]
# In this warmup, we'll see how to redo the previous warmup using pandas methods.
#
# To get started, we'll read the feedback into a pandas DataFrame.

# %%
import pandas as pd

# %%
feedback = pd.read_json("../data/part3_store_feedback.json")
feedback
# Out:
#    store_number                                           feedback
# 0           101  [7, Great service, 9.0, N/A, 8, Poor selection...
# 1           102                [Excellent, 8.0, 5, Loved it!, 3.5]
# 2           103  [Amazing, 10, 6.5, Slow service, 8, Average, 2...
# 3           104  [9.5, Fantastic, 6, Too crowded, 7.5, No compl...
# 4           105  [Great products, 8, Too pricey, 9.0, Will return]
# 5           106  [Helpful staff, Love the ambiance, Very organi...
# 6           107  [4, Needs improvement, 7.0, Unfriendly staff, ...
# 7           108  [10, 9.0, Best experience, 6, 7.5, Could be be...
# 8           109    [Average service, Too busy, 5.0, 3, Noisy, 6.5]
# 9           110                [Unorganized, No assistance, Messy]

# %% [markdown]
# ## Part 1
#
# Use the [explode method](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.explode.html) to split each store's feedback out across multiple rows. The resulting DataFrame should have 59 rows.

# %% [markdown]
# ## Part 2
# Convert the column containing the feedback values into a numeric DataType. Any non-numeric values can be replaced with NaN.

# %% [markdown]
# ## Part 3
#
# Calculate the average by store_number and find the store with the highest average feedback value.
